# %% [markdown]
# # Matplot test

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[4,5,3])
plt.show()

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.title('This is a test graph')
plt.plot([1,2,3],[2,1,5], label = 'random graph')
plt.legend()
plt.show()
